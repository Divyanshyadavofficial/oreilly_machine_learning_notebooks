# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras

# %%
housing = fetch_california_housing()

# %%
Xtrain_full,Xtest,ytrain_full,ytest = train_test_split(housing.data,housing.target)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
Xtrain_full, ytrain_full)

# %%
scaler = StandardScaler()
X_train  = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
Xtest = scaler.transform(Xtest)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30,activation="relu",input_shape = X_train.shape[1:]),
    keras.layers.Dense(1)
])
model.compile(loss="mean_squared_error",optimizer="sgd")
history = model.fit(X_train,y_train,epochs=20,
                    validation_data=(X_valid,y_valid))
mse_test = model.evaluate(Xtest,ytest)
X_new = Xtest[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 919us/step - loss: 1.4587 - val_loss: 0.5547
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.9328 - val_loss: 0.4723
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.4933 - val_loss: 0.4542
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.4426 - val_loss: 0.7313
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.4597 - val_loss: 0.4488
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.5181 - val_loss: 0.4142
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.4585 - val_loss: 0.4169
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.4111 - val_loss: 0.4091
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.4100 - val_loss: 0.3991
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.4034 - val_loss: 0.3975
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.3993 - val_loss: 0.3918
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - loss: 0.3982 - val_loss: 0.3840
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.3979 - val_loss: 0.3898
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.3846 - val_loss: 0.3757
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.3643 - val_loss: 0.3710
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.3706 - val_loss: 0.3767
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.3663 - val_loss: 0.3646
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.3705 - val_loss: 0.3681
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.3721 - val_loss: 0.3596
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.3706 - val_loss: 0.3624
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.3591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30,activation="relu")(input_)
hidden2 = keras.layers.Dense(30,activation="relu")(hidden1)
concat = keras.layers.Concatenate()([input_,hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_],outputs=[output])

model.compile(loss="mean_squared_error",optimizer="sgd")
history = model.fit(X_train,y_train,epochs=20,
                    validation_data=(X_valid,y_valid))
mse_test = model.evaluate(Xtest,ytest)
X_new = Xtest[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 332/363 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 1.3082
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_3']
# Received: inputs=Tensor(shape=(None, 8))
#   warnings.warn(msg)
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - loss: 1.2696 - val_loss: 0.4911
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.9448 - val_loss: 0.5621
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.5672 - val_loss: 3.0228
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 8.8865 - val_loss: 4.8210
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 259.6925 - val_loss: 67.9109
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: nan - val_loss: nan
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: nan - val_loss: nan
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: nan - val_loss: nan
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: nan - val_loss: nan
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: nan - val_loss: nan
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: nan - val_loss: nan
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: nan - val_loss: nan
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: nan - val_loss: nan
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: nan - val_loss: nan
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: nan - val_loss: nan
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: nan - val_loss: nan
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: nan - val_loss: nan
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: nan - val_loss: nan
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: nan - val_loss: nan
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: nan - val_loss: nan
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: nan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_3']
# Received: inputs=Tensor(shape=(3, 8))
#   warnings.warn(msg)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('img1.png')  


plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
X_train_A = X_train[:, :5] 
X_train_B = X_train[:, 5:]  

X_valid_A = X_valid[:, :5]
X_valid_B = X_valid[:, 5:]

Xtest_A = Xtest[:, :5]
Xtest_B = Xtest[:, 5:]

# %%
input_A = keras.layers.Input(shape=(5,),name="wide_input")
input_B = keras.layers.Input(shape=(3,),name = "deep_input")
hidden1 = keras.layers.Dense(30,activation="relu")(input_B)
hidden2 = keras.layers.Dense(30,activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A,hidden2])
output = keras.layers.Dense(1,name="output")(concat)
model = keras.Model(inputs=[input_A,input_B],outputs=[output])

model.compile(loss="mean_squared_error",optimizer="sgd")
history = model.fit([X_train_A,X_train_B],y_train,epochs=20,
                    validation_data=([X_valid_A,X_valid_B],y_valid))
mse_test = model.evaluate([Xtest_A,Xtest_B],ytest)
X_new = [Xtest_A[:3], Xtest_B[:3]]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - loss: 1.5951 - val_loss: 0.5128
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.5317 - val_loss: 0.4552
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.4654 - val_loss: 0.4621
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 2.3003 - val_loss: 0.4119
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.4291 - val_loss: 0.3963
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.4259 - val_loss: 0.4060
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.4046 - val_loss: 0.3822
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.3971 - val_loss: 0.3766
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.3797 - val_loss: 0.3875
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.3905 - val_loss: 0.3699
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3825 - val_loss: 0.3706
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.3806 - val_loss: 0.3737
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3811 - val_loss: 0.3735
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.3702 - val_loss: 0.3733
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.3792 - val_loss: 0.3640
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.3640 - val_loss: 0.3553
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3696 - val_loss: 0.3670
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3754 - val_loss: 0.3623
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.3747 - val_loss: 0.3597
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.3663 - val_loss: 0.3533
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 0.3444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
img = mpimg.imread('img2.png')  


plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
input_A = keras.layers.Input(shape=(5,),name="wide_input")
input_B = keras.layers.Input(shape=(3,),name = "deep_input")
hidden1 = keras.layers.Dense(30,activation="relu")(input_B)
hidden2 = keras.layers.Dense(30,activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A,hidden2])
output = keras.layers.Dense(1,name="main_output")(concat)
aux_output = keras.layers.Dense(1,name="aux_output")(hidden2)
model = keras.Model(inputs=[input_A,input_B],outputs=[output,aux_output])

model.compile(loss=["mse","mse"],loss_weights=[0.9,0.1],optimizer="sgd")
history = model.fit([X_train_A,X_train_B],[y_train,y_train],epochs=20,
                    validation_data=([X_valid_A,X_valid_B],[y_valid,y_valid]))
mse_test = model.evaluate([Xtest_A,Xtest_B],[ytest,ytest])
total_loss, main_loss, aux_loss = model.evaluate(
[Xtest_A, Xtest_B], [ytest, ytest])
X_new = [Xtest_A[:3], Xtest_B[:3]]
y_pred_main, y_pred_aux = model.predict(X_new)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - aux_output_loss: 3.2559 - loss: 1.3397 - main_output_loss: 1.1268 - val_aux_output_loss: 1.1840 - val_loss: 0.5737 - val_main_output_loss: 0.5059
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - aux_output_loss: 1.2543 - loss: 0.8841 - main_output_loss: 0.8429 - val_aux_output_loss: 1.0685 - val_loss: 0.5382 - val_main_output_loss: 0.4793
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - aux_output_loss: 1.1116 - loss: 0.6054 - main_output_loss: 0.5491 - val_aux_output_loss: 0.9794 - val_loss: 0.5079 - val_main_output_loss: 0.4555
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step